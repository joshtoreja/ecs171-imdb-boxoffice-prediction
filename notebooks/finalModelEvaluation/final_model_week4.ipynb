# %%
# Core libraries
import pandas as pd #data manipulation and tabluar operation
import numpy as np #numerical operations and transformation

# Visualization
import matplotlib.pyplot as plt #base plotting
import seaborn as sns #statistical visualization

# Model selection
from sklearn.model_selection import (
    train_test_split, #train/ test splitting
    StratifiedKFold, #stratified cross validation
    RandomizedSearchCV, #hyperparameter tuning
    cross_val_score #cross validation scoring
)

# Preprocessing
from sklearn.preprocessing import StandardScaler, OneHotEncoder #scaling + categorical encoding
from sklearn.compose import ColumnTransformer #apply different preprocessing to different columns
from sklearn.pipeline import Pipeline #end to end modeling pipeline

# Metrics
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    roc_curve,
    precision_recall_curve,
    confusion_matrix
)

# Model
from xgboost import XGBClassifier #gradient boosted tree model

# Saving
import joblib
import os

# %%
df = pd.read_csv("../../data/processed/tmdb_clean.csv")

print("Dataset shape:", df.shape) # print dataset shape
df.head()#preview of first few rows
# Out:
# Dataset shape: (16718, 26)
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
#    popularity                       poster_path  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'title', 'vote_average', 'vote_count', 'status', 'release_date',
#        'revenue', 'runtime', 'adult', 'backdrop_path', 'budget', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'tagline', 'genres',
#        'production_companies', 'production_countries', 'spoken_languages',
#        'keywords', 'ROI', 'profitable'],
#       dtype='object')

# %%
# Target
y = df["profitable"] #binary profitability label created earlier (ROI threshold already applied)

# Release year
df["release_year"] = pd.to_datetime(df["release_date"]).dt.year

# Release month
df["release_month"] = pd.to_datetime(df["release_date"]).dt.month

# Seasonal features
df["is_summer"] = df["release_month"].isin([5,6,7]).astype(int) #summer release indicator
df["is_holiday"] = df["release_month"].isin([11,12]).astype(int) #holiday release indicator

# Log transform budget
df["log_budget"] = np.log1p(df["budget"]) #apply log1p to reduce heavy skew in budget distribution

# Runtime bucket
df["long_movie"] = (df["runtime"] > 120).astype(int) #binary indicator for long films

# Numerical features
numerical_features = [
    "log_budget",
    "runtime",
    "release_year",
    "is_summer",
    "is_holiday",
    "long_movie"
]

# Categorical features
categorical_features = [
    "genres",
    "production_companies",
    "production_countries"
]

X = df[numerical_features + categorical_features] #combine into feature matrix

print("X shape:", X.shape)
print("Class balance:\n", y.value_counts())
# Out:
# X shape: (16718, 9)
# Class balance:
#  profitable
# 0    10907
# 1     5811
# Name: count, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

print("Train shape:", X_train.shape)
print("Test shape:", X_test.shape)
# Out:
# Train shape: (13374, 9)
# Test shape: (3344, 9)

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numerical_features),#scale numerical features
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_features) #one-hot encode categorical features
    ]
)

# %%
model = XGBClassifier(
    objective="binary:logistic", #binary classifcation
    eval_metric="logloss", #optimization metric
    random_state=42, #reproducability
    scale_pos_weight=1.2  # mild imbalance adjustment 
)

pipeline = Pipeline([ #combine into pipeline
    ("preprocessor", preprocessor),
    ("model", model)
])

# %%
#hyperparameter search space
param_grid = {
    "model__n_estimators": [400, 600, 800],# number of bosting trees
    "model__learning_rate": [0.03, 0.05, 0.07], #step size shrinkage
    "model__max_depth": [3, 4, 5], #tree depth
    "model__subsample": [0.7, 0.8], #row sampling
    "model__colsample_bytree": [0.7, 0.8], #feature sampling
    "model__min_child_weight": [1, 3] #regularization
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42) # 5-fold stratified cross-validaton

search = RandomizedSearchCV(
    pipeline,
    param_distributions=param_grid,
    n_iter=25,# number of random parameter combinations
    scoring="f1",  # optimize for F1 score
    cv=cv,
    verbose=1,
    n_jobs=-1, # prallel processing
    random_state=42
)

search.fit(X_train, y_train) #perform randomized hyperparameter tuning

print("Best Params:", search.best_params_) #print the best hyperparameters
print("Best CV F1:", search.best_score_)

pipeline = search.best_estimator_ #retrieve the best pipeline
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# Best Params: {'model__subsample': 0.7, 'model__n_estimators': 800, 'model__min_child_weight': 1, 'model__max_depth': 5, 'model__learning_rate': 0.05, 'model__colsample_bytree': 0.8}
# Best CV F1: 0.444856399572182

# %%
cv_auc = cross_val_score( #evaluate ROC-AUC using cross validation
    pipeline,
    X_train,
    y_train,
    cv=cv,
    scoring="roc_auc"
)

print("CV ROC-AUC:", cv_auc.mean())
# Out:
# CV ROC-AUC: 0.6697848561612677

# %%
from sklearn.model_selection import cross_validate

# Define scoring metrics
scoring = {
    "accuracy": "accuracy",
    "precision": "precision",
    "recall": "recall",
    "f1": "f1",
    "roc_auc": "roc_auc"
}

# Perform cross-validation on the best pipeline
cv_results = cross_validate(
    pipeline,
    X_train,
    y_train,
    cv=cv,
    scoring=scoring,
    return_train_score=False
)

# Compute mean CV metrics
cv_accuracy = cv_results["test_accuracy"].mean()
cv_precision = cv_results["test_precision"].mean()
cv_recall = cv_results["test_recall"].mean()
cv_f1 = cv_results["test_f1"].mean()
cv_roc_auc = cv_results["test_roc_auc"].mean()

print("CV Accuracy:", cv_accuracy)
print("CV Precision:", cv_precision)
print("CV Recall:", cv_recall)
print("CV F1:", cv_f1)
print("CV ROC-AUC:", cv_roc_auc)
# Out:
# CV Accuracy: 0.6820689365925947
# CV Precision: 0.5660314714216639
# CV Recall: 0.36674097480236584
# CV F1: 0.444856399572182
# CV ROC-AUC: 0.6697848561612677

# %%
pipeline.fit(X_train, y_train) #train final model on training data
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['log_budget', 'runtime',
#                                                    'release_year', 'is_summer',
#                                                    'is_holiday',
#                                                    'long_movie']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['genres',
#                                                    'production_companies',
#                                                    'production_countries'])])),
#                 ('model',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample...
# ...

# %%
y_val_proba = pipeline.predict_proba(X_train)[:, 1] #get predicted probabilities on training data

precision, recall, thresholds = precision_recall_curve(y_train, y_val_proba) # precision recall curve

f1_scores = 2 * (precision * recall) / (precision + recall + 1e-9) #compute F1 at each threshold

#identify threshold maximzing F1
best_idx = np.argmax(f1_scores)
best_threshold = thresholds[best_idx]

print("Best Threshold:", best_threshold)
# Out:
# Best Threshold: 0.3701714

# %%
y_test_proba = pipeline.predict_proba(X_test)[:, 1] #predict probabilities on test set
y_test_pred = (y_test_proba >= best_threshold).astype(int) # applky optimized threshold

#print evaluation metrics
print("TEST Accuracy:", accuracy_score(y_test, y_test_pred))
print("TEST Precision:", precision_score(y_test, y_test_pred))
print("TEST Recall:", recall_score(y_test, y_test_pred))
print("TEST F1:", f1_score(y_test, y_test_pred))
print("TEST ROC-AUC:", roc_auc_score(y_test, y_test_proba))
# Out:
# TEST Accuracy: 0.63127990430622
# TEST Precision: 0.47644326476443266
# TEST Recall: 0.6179001721170396
# TEST F1: 0.538029224428625
# TEST ROC-AUC: 0.6806485467863335

# %%
from sklearn.metrics import roc_curve

# %%
import os

# Create directory if it doesn't exist
os.makedirs("reports/figures/final_model", exist_ok=True)

# Compute ROC
fpr, tpr, _ = roc_curve(y_test, y_test_proba)

plt.figure()
plt.plot(fpr, tpr, label="XGBoost (strict)")
plt.plot([0, 1], [0, 1], linestyle="--")
plt.title("ROC Curve (Test Set)")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()

# Save figure
plt.savefig("reports/figures/final_model/xgboost_strict_roc.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
import os

# Create directory if it doesn't exist
os.makedirs("reports/figures/final_model", exist_ok=True)

cm = confusion_matrix(y_test, y_test_pred)

plt.figure(figsize=(6,5))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    cbar=False
)

plt.title("Confusion Matrix (Test Set)")
plt.xlabel("Predicted")
plt.ylabel("Actual")

# Save figure
plt.savefig(
    "reports/figures/final_model/xgboost_strict_confusion_matrix.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
os.makedirs("./artifacts", exist_ok=True)
joblib.dump(pipeline, "./artifacts/final_model.pkl")

print("Model saved.")
# Out:
# Model saved.

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
import matplotlib.pyplot as plt
import numpy as np
import os

# Get predicted probabilities (NOT class predictions)
y_scores = pipeline.predict_proba(X_test)[:, 1]

# Compute precision-recall values
precision, recall, thresholds = precision_recall_curve(y_test, y_scores)

# Compute average precision (area under PR curve)
ap_score = average_precision_score(y_test, y_scores)

# Create directory if needed
os.makedirs("reports/figures/final_model", exist_ok=True)

# Plot PR curve
plt.figure(figsize=(6,5))
plt.plot(recall, precision, label=f"PR Curve (AP = {ap_score:.3f})")

# Add no-skill baseline
positive_rate = np.mean(y_test)
plt.axhline(
    y=positive_rate,
    linestyle="--",
    label=f"No Skill (={positive_rate:.3f})"
)

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve (Held-Out Test Set)")
plt.legend()

# Save figure
plt.savefig(
    "reports/figures/final_model/xgBoostPrCurve.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()
plt.show()

print("PR curve saved.")
# Out:
# PR curve saved.
